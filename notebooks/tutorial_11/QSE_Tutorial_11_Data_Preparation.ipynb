# %% [markdown]
# # Quantitative Spatial Economics
#
# ## Tutorial Topic 12: Eliminate the Ostseeautobahn from the network
#
# Humboldt University Berlin & Berlin School of Economics
#
# Authors:
# [Dominik Bursy](dominik.bursy@icloud.com),
# [Lars Felder](lars.felder@fu-berlin.de),
# [Kate Bablyak](kateryna.bablyak@student.hu-berlin.de),
# [Marlon Krippendorf](marlon.krippendorf@fu-berlin.de)
#
# Last Update: July 2025

# %% [markdown]
# ---

# %% [markdown]
# ## Import Packages <a class="anchor" id="packages"></a>

# %%
from pathlib import Path
import geopandas as gpd
import folium

import warnings
warnings.filterwarnings('ignore')

# %%
## Set Root Directory
ROOT_FOLDER = str(Path().absolute().parent.parent)
print(ROOT_FOLDER)
# Out:
# /Users/dominik.bursy/Documents/8_PhD/2_Second_Year/qse_collaboration

# %% [markdown]
# ## Import Road Network

# %%
gdf_roads = gpd.read_file(f'{ROOT_FOLDER}/data/Shapefiles-2022/Germany/ROADS/ROADS_2015.shp')

# %% [markdown]
# ## Identify and Remove the Ostseeautobahn

# %%
## Ostseeautobahn corresponds to Bundesautobahn A20 
## Street category of Autobahn corresponds to 1 
## https://de.wikipedia.org/wiki/Bundesautobahn_20 

condition = (gdf_roads['BEZ'].str.contains('A20', na=False)) & (gdf_roads['street_cat'] == 1)

# %%
# Create map centered on the shapefile's centroid
m = folium.Map(
    location=[gdf_roads.loc[condition].to_crs(epsg=4326).centroid.y.mean(),
              gdf_roads.loc[condition].to_crs(epsg=4326).centroid.x.mean()], 
    zoom_start=7
)

# Add shapefile as GeoJSON
folium.GeoJson(
    gdf_roads.loc[condition, ['FID_Roads_', 'BEZ', 'geometry']],
    name="Shapefile Layer",
    color="red",
    tooltip=folium.GeoJsonTooltip(fields=['FID_Roads_', 'BEZ'])  # Show first 3 fields
).add_to(m)

# Display map in Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d75da6e4f390f66385c2f52e95c15ede {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d75da6e4f390f66385c2f52e95c15ede&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d75da6e4f390f66385c2f52e95c15ede = L.map(
#                 &quot;map_d75da6e4f390f66385c2f52e95c15ede&quot;,
#                 {
#                     center: [53.83045134381728, 12.323189937630797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_757fa166b74bbb10f92188b20fd565bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_757fa166b74bbb10f92188b20fd565bf.addTo(map_d75da6e4f390f66385c2f52e95c15ede);
#
#
#
#         function geo_json_6625f305321f831ac812605243b79fae_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6625f305321f831ac812605243b79fae = L.geoJson(null, {
#                 onEachFeature: geo_json_6625f305321f831ac812605243b79fae_onEachFeature,
#
#             ...{
#   &quot;color&quot;: &quot;red&quot;,
# }
#         });
#
#         function geo_json_6625f305321f831ac812605243b79fae_add (data) {
#             geo_json_6625f305321f831ac812605243b79fae
#                 .addData(data);
#         }
#             geo_json_6625f305321f831ac812605243b79fae_add({&quot;bbox&quot;: [10.341611475779303, 53.23544088272967, 14.014477546956027, 54.09110344192048], &quot;features&quot;: [{&quot;bbox&quot;: [10.55386381866464, 53.90106819457535, 10.569451553891467, 53.91080573921178], &quot;geometry&quot;: {&quot;coordinates&quot;: [[10.569451553891467, 53.90106819457535], [10.569176368751204, 53.901984364882125], [10.568875806578518, 53.90285379732545], [10.568329823107685, 53.90351677469082], [10.566795526947017, 53.90485603440209], [10.565275820940014, 53.90584494063556], [10.563740767993979, 53.906788920637425], [10.561886227183658, 53.90776897110207], [10.559696814021205, 53.90867729208843], [10.55752567641163, 53.90949826273099], [10.55386381866464, 53.91080573921178]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;268137&quot;, &quot;properties&quot;: {&quot;BEZ&quot;: &quot;A20&quot;, &quot;FID_Roads_&quot;: 288311}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [10.523760488799473, 53.91080573921178, 10.55386381866464, 53.916266696932986], &quot;geometry&quot;: {&quot;coordinates&quot;: [[10.55386381866464, 53.91080573921178], [10.548052383406546, 53.912804352629834], [10.545335042309507, 53.91358547344452], [10.543376518769215, 53.91406350258699], [10.540679847394022, 53.91463481103188], [10.5382849232942, 53.9150752531654], [10.536433287034717, 53.91533724108525], [10.534541349674223, 53.91557544590549], [10.532683426534797, 53.91579259450233], [10.529959943784895, 53.91599089709697], [10.526566938660654, 53.916189285233294], [10.523760488799473, 53.916266696932986]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;268196&quot;, &quot;properties&quot;: {&quot;BEZ&quot;: &quot;A20&quot;, &quot;FID_Roads_&quot;: 288311}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [10.36289627542193, 53.918137197399126, 10.382975003050793, 53.918883307547716], &quot;geometry&quot;: {&quot;coordinates&quot;: [[10.36289627542193, 53.918883307547716], [10.382975003050793, 53.918137197399126]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;268208&quot;, &quot;properties&quot;: {&quot;BEZ&quot;: &quot;A20&quot;, &quot;FID_Roads_&quot;: 288353}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [10.341611475779303, 53.918883307547716, 10.36289627542193, 53.92116562691177], &quot;geometry&quot;: {&quot;coordinates&quot;: [[10.341611475779303, 53.92116562691177], [10.344730005597697, 53.92070814828638], [10.34968392621162, 53.920071733435556], [10.354022434841852, 53.91960081568525], [10.361036418210839, 53.919001449152], [10.36289627542193, 53.918883307547716]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;268235&quot;, &quot;p

# %% [markdown]
# ## Export Adjusted Road Network

# %%
## Export Road Network
Path(f'{ROOT_FOLDER}/notebooks/tutorial_11/data').mkdir(parents=True, exist_ok=True)
gdf_roads.loc[~condition].to_file(f'{ROOT_FOLDER}/notebooks/tutorial_11/data/ROADS_2015_ADJUSTED.shp')

# %% [markdown]
# ---
